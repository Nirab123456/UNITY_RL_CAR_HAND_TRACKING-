# %%
        # // public RpcService(string gameObjectName) : base(gameObjectName) { }


        # // [JsonRpcMethod]
        # // public void ReceiveHandPoints(List<(int, int)> handPoints)
        # // {
        # //     Dictionary<string, List<Vector2>> convertedPoints = new Dictionary<string, List<Vector2>>();

        # //     // Map the point indices to their corresponding Unity point names
        # //     Dictionary<int, string> pointMap = new Dictionary<int, string>()
        # //     {
        # //         { 1, "THUMB_CMC" },
        # //         { 2, "THUMB_MCP" },
        # //         { 3, "THUMB_IP" },
        # //         { 4, "THUMB_TIP" },
        # //         { 5, "INDEX_FINGER_MCP" },
        # //         { 6, "INDEX_FINGER_PIP" },
        # //         { 7, "INDEX_FINGER_DIP" },
        # //         { 8, "INDEX_FINGER_TIP" },
        # //         { 9, "MIDDLE_FINGER_MCP" },
        # //         { 10, "MIDDLE_FINGER_PIP" },
        # //         { 11, "MIDDLE_FINGER_DIP" },
        # //         { 12, "MIDDLE_FINGER_TIP" },
        # //         { 13, "RING_FINGER_MCP" },
        # //         { 14, "RING_FINGER_PIP" },
        # //         { 15, "RING_FINGER_DIP" },
        # //         { 16, "RING_FINGER_TIP" },
        # //         { 17, "PINKY_MCP" },
        # //         { 18, "PINKY_PIP" },
        # //         { 19, "PINKY_DIP" },
        # //         { 20, "PINKY_TIP" }
        # //     };

        # //     // Convert the points to Unity coordinates and group them by point name
        # //     foreach ((int index, int y) in handPoints)
        # //     {
        # //         string pointName = pointMap[index];
        # //         Vector2 point = new Vector2(index, y);

        # //         if (!convertedPoints.ContainsKey(pointName))
        # //         {
        # //             convertedPoints[pointName] = new List<Vector2>();
        # //         }

        # //         convertedPoints[pointName].Add(point);
        # //     }

        # //     // Process the received hand points
        # //     foreach (KeyValuePair<string, List<Vector2>> entry in convertedPoints)
        # //     {
        # //         string pointName = entry.Key;
        # //         List<Vector2> points = entry.Value;

        # //         // Update the position of the corresponding hand point
        # //         UpdatePosition(pointName, points);

        # //         // Print the hand points in the Unity console
        # //         Debug.Log($"Hand Point: {pointName}");
        # //         foreach (Vector2 point in points)
        # //         {
        # //             Debug.Log($"Position: x={point.x}, y={point.y}");
        # //         }
        # //     }
        # // }


        # // [JsonRpcMethod]

        # // private void UpdatePosition(string pointName, List<Vector2> points)
        # // {
        # //     // TODO: Implement the logic to update the position of the corresponding hand point
        # //     // Use the pointName and points list to update the position in your scene or game logic
        # // }
